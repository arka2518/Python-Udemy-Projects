# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    679     83   John  January      Q1
# 1  2023-01-02       B   West    787     81   Mary  January      Q1
# 2  2023-01-03       C  North    411     11    Bob  January      Q1
# 3  2023-01-04       D  South    368     19  Alice  January      Q1
# 4  2023-01-05       A   East    700     39   John  January      Q1
# 5  2023-01-06       B   West    344     73   Mary  January      Q1
# 6  2023-01-07       C  North    971     95    Bob  January      Q1
# 7  2023-01-08       D  South    712     71  Alice  January      Q1
# 8  2023-01-09       A   East    901     17   John  January      Q1
# 9  2023-01-10       B   West    129     12   Mary  January      Q1
# 10 2023-01-11       C  North    349     17    Bob  January      Q1
# 11 2023-01-12       D  South    649     48  Alice  January      Q1
# 12 2023-01-13       A   East    268     78   John  January      Q1
# 13 2023-01-14       B   West    519     71   Mary  January      Q1
# 14 2023-01-15       C  North    300     31    Bob  January      Q1
# 15 2023-01-16       D  South    105     57  Alice  January      Q1
# 16 2023-01-17       A   East    239     77   John  January      Q1
# 17 2023-01-18       B   West    673     47   Mary  January      Q1
# 18 2023-01-19       C  North    786     85    Bob  January      Q1
# 19 2023-01-20       D  South    611     25  Alice  January      Q1

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product', aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     679.0    NaN    NaN    NaN
# North      NaN    NaN  411.0    NaN
# South      NaN    NaN    NaN  611.0
# West       NaN  519.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     557.4    NaN    NaN    NaN  58.8   NaN   NaN   NaN
# North      NaN    NaN  563.4    NaN   NaN   NaN  47.8   NaN
# South      NaN    NaN    NaN  489.0   NaN   NaN   NaN  44.0
# West       NaN  490.4    NaN    NaN   NaN  56.8   NaN   NaN

# %%
# Cross Tabs

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
