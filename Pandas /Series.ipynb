# %%
import numpy as np
import pandas as pd

# %%
# Creating Series

# %%
lables = ['a', 'b', 'c', 'd']
list = [10, 15, 20, 25]
arr = np.array([10, 20, 30, 40])
dict = {1:10, 2:15, 3:20, 4:25}

# %%
pd.Series(list)
# Out:
# 0    10
# 1    15
# 2    20
# 3    25
# dtype: int64

# %%
pd.Series(list, index=lables)
# Out:
# a    10
# b    15
# c    20
# d    25
# dtype: int64
