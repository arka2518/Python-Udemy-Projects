# %%
import numpy as np
import pandas as pd

# %%
# Creating a DataFrame

# %%
data = {
    'Name': ['Arka', 'Aditya', 'Anurag', 'Lakshya'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [75000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age      City  Salary
# 0     Arka   28  New York   75000
# 1   Aditya   34     Paris   70000
# 2   Anurag   29    Berlin   62000
# 3  Lakshya   42    London   85000

# %%
data_list = [
    ['Arka', 28, 'New York', 65000],
    ['Aditya', 34, 'Paris', 70000],
    ['Anurag', 29, 'Berlin', 62000],
    ['Lakshay', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#       Name  Age      City  Salary
# 0     Arka   28  New York   65000
# 1   Aditya   34     Paris   70000
# 2   Anurag   29    Berlin   62000
# 3  Lakshay   42    London   85000

# %%
# Selection and Indexing of Columns

# %%
df2["Name"]
# Out:
# 0       Arka
# 1     Aditya
# 2     Anurag
# 3    Lakshay
# Name: Name, dtype: object

# %%
df2['Salary']
# Out:
# 0    65000
# 1    70000
# 2    62000
# 3    85000
# Name: Salary, dtype: int64

# %%
df2[['Name', 'Salary']]
# Out:
#       Name  Salary
# 0     Arka   65000
# 1   Aditya   70000
# 2   Anurag   62000
# 3  Lakshay   85000

# %%
# Creating a new column

# %%
df2['Designation'] = ['Data Analyst', 'SDE', 'Marketing Head', 'Project Manager']
df2
# Out:
#       Name  Age      City  Salary      Designation
# 0     Arka   28  New York   65000     Data Analyst
# 1   Aditya   34     Paris   70000              SDE
# 2   Anurag   29    Berlin   62000   Marketing Head
# 3  Lakshay   42    London   85000  Project Manager

# %%
# Removing Columns

# %%
df2.drop('Age', axis=1, inplace=True)      # inplace is used for permanent removal of columns
df2
# Out:
#       Name      City  Salary      Designation
# 0     Arka  New York   65000     Data Analyst
# 1   Aditya     Paris   70000              SDE
# 2   Anurag    Berlin   62000   Marketing Head
# 3  Lakshay    London   85000  Project Manager

# %%
df2.drop(['Name', 'City'], axis=1)
# Out:
#    Salary      Designation
# 0   65000     Data Analyst
# 1   70000              SDE
# 2   62000   Marketing Head
# 3   85000  Project Manager

# %%
df2.drop(2, axis=0)
# Out:
#       Name      City  Salary      Designation
# 0     Arka  New York   65000     Data Analyst
# 1   Aditya     Paris   70000              SDE
# 3  Lakshay    London   85000  Project Manager

# %%
# Selecting Rows

# %%
df2
# Out:
#       Name      City  Salary      Designation
# 0     Arka  New York   65000     Data Analyst
# 1   Aditya     Paris   70000              SDE
# 2   Anurag    Berlin   62000   Marketing Head
# 3  Lakshay    London   85000  Project Manager

# %%
df2.loc[3]
# Out:
# Name                   Lakshay
# City                    London
# Salary                   85000
# Designation    Project Manager
# Name: 3, dtype: object

# %%
df2.loc[[0, 3]]
# Out:
#       Name      City  Salary      Designation
# 0     Arka  New York   65000     Data Analyst
# 3  Lakshay    London   85000  Project Manager

# %%
df2.iloc[2]
# Out:
# Name                   Anurag
# City                   Berlin
# Salary                  62000
# Designation    Marketing Head
# Name: 2, dtype: object

# %%
# Selecting subsets of rows and columns

# %%
df2.loc[[0, 1]][['Name', 'Designation']]
# Out:
#      Name   Designation
# 0    Arka  Data Analyst
# 1  Aditya           SDE

# %%
df2.loc[[2, 3]][['Name', 'City']]
# Out:
#       Name    City
# 2   Anurag  Berlin
# 3  Lakshay  London

# %%
# Conditional selection

# %%
df2
# Out:
#       Name      City  Salary      Designation
# 0     Arka  New York   65000     Data Analyst
# 1   Aditya     Paris   70000              SDE
# 2   Anurag    Berlin   62000   Marketing Head
# 3  Lakshay    London   85000  Project Manager

# %%
df2[(df2['Salary'] > 65000) & (df2['City'] == "Paris")]
# Out:
#      Name   City  Salary Designation
# 1  Aditya  Paris   70000         SDE
